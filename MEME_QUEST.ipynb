# %% [markdown]
# <a href="https://colab.research.google.com/github/jennigerortega/PROGCOM-B/blob/main/MEME_QUEST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MEME QUEST EPOCA DE PARCIALES

# %%
motivación=int(input("Del 1 al 10 cuánto es tu motivación hoy? "))
while motivación >0:
  print("Voy a estudiar")

print("Mejor mañana Zzzzz")
# Out:
# Del 1 al 10 cuánto es tu motivación hoy? 0
# Mejor mañana Zzzzz
